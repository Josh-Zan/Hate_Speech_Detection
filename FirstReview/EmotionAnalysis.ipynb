# %% [markdown]
# Importing Packages

# %%
import pandas as pd
import numpy as np

# %%
# text preprocessing
from nltk import word_tokenize
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords
import re

# plots and metrics
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, confusion_matrix, f1_score

# feature extraction / vectorization
from sklearn.feature_extraction.text import TfidfVectorizer

# classifiers
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline

# save and load a file
import pickle

# %% [markdown]
# Importing Dataset

# %%
# importing training data
df_train = pd.read_csv('./dailydialog_emotion_stimulus_isear/data_train.csv')

# importing testing data
df_test = pd.read_csv('./dailydialog_emotion_stimulus_isear/data_test.csv')

# %% [markdown]
# Exploratory Data Analysis (EDA)

# %%
# concatinating training and testing dataset
total_data = pd.concat([df_train, df_test])

# training dataset
print('Size of training dataset:', len(df_train))
print(df_train.Emotion.value_counts())
print()

# testing dataset
print('Size of testing dataset:', len(df_test))
print(df_test.Emotion.value_counts())
print()

# total dataset
print('Total size of dataset:', len(total_data))
print(total_data.Emotion.value_counts())
# Out:
# Size of training dataset: 7934
# sadness    1641
# joy        1619
# neutral    1616
# anger      1566
# fear       1492
# Name: Emotion, dtype: int64
#
# Size of testing dataset: 3393
# joy        707
# anger      693
# fear       679
# sadness    676
# neutral    638
# Name: Emotion, dtype: int64
#
# Total size of dataset: 11327
# joy        2326
# sadness    2317
# anger      2259
# neutral    2254
# fear       2171
# Name: Emotion, dtype: int64

# %%
# total Dataset
total_data.head(10)
# Out:
#    Emotion                                               Text
# 0  neutral   There are tons of other paintings that I thin...
# 1  sadness  Yet the dog had grown old and less capable , a...
# 2     fear  When I get into the tube or the train without ...
# 3     fear  This last may be a source of considerable disq...
# 4    anger  She disliked the intimacy he showed towards so...
# 5  sadness  When my family heard that my Mother's cousin w...
# 6      joy  Finding out I am chosen to collect norms for C...
# 7    anger  A spokesperson said : ` Glen is furious that t...
# 8  neutral                                             Yes .
# 9  sadness  When I see people with burns I feel sad, actua...

# %%
def preprocess_and_tokenize(data):    

    #remove html markup
    data = re.sub("(<.*?>)", "", data)

    #remove urls
    data = re.sub(r'http\S+', '', data)
    
    #remove hashtags and @names
    data= re.sub(r"(#[\d\w\.]+)", '', data)
    data= re.sub(r"(@[\d\w\.]+)", '', data)

    #remove punctuation and non-ascii digits
    data = re.sub("(\\W|\\d)", " ", data)
    
    #remove whitespace
    data = data.strip()
    
    # tokenization with nltk
    data = word_tokenize(data)
    
    # stemming with nltk
    porter = PorterStemmer()
    stem_data = [porter.stem(word) for word in data]
        
    return stem_data

# %%
x_train = df_train.Text
x_test = df_test.Text

y_train = df_train.Emotion
y_test = df_test.Emotion

# %%
# TFIDF, unigrams and bigrams
vect = TfidfVectorizer(tokenizer = preprocess_and_tokenize, sublinear_tf = True, norm = 'l2', ngram_range = (1, 3))

# fit on our complete corpus
vect.fit_transform(total_data.Text)

# transform testing and training datasets to vectors
X_train_vect = vect.transform(x_train)
X_test_vect = vect.transform(x_test)

# %%
vect.vocabulary_
# Out:
# {'there': 161383,
#  'are': 17016,
#  'ton': 169798,
#  'of': 111540,
#  'other': 118463,
#  'paint': 120612,
#  'that': 152048,
#  'i': 75663,
#  'think': 163547,
#  'better': 25693,
#  'there are': 161405,
#  'are ton': 17482,
#  'ton of': 169799,
#  'of other': 113324,
#  'other paint': 118643,
#  'paint that': 120629,
#  'that i': 152508,
#  'i think': 78639,
#  'think are': 163568,
#  'are better': 17088,
#  'there are ton': 161423,
#  'are ton of': 17483,
#  'ton of other': 169800,
#  'of other paint': 113330,
#  'other paint that': 118644,
#  'paint that i': 120630,
#  'that i think': 152588,
#  'i think are': 78642,
#  'think are better': 163569,
#  'yet': 190983,
#  'the': 153603,
#  'dog': 44144,
#  'had': 64845,
#  'grown': 64206,
#  'old': 115435,
#  'and': 11275,
#  'less': 91361,
#  'capabl': 31621,
#  'one': 116795,
#  'day': 39803,
#  'gilli': 60881,
#  'come': 35421,
#  'explain': 50052,
#  'with': 187133,
#  'great': 63632,
#  'sorrow': 143990,
#  'suffer': 147875,
#  'a': 0,
#  'stroke': 146839,
#  'must': 103541,
#  'be': 22186,
#  'put': 126751,
#  'down': 44736,
#  'yet the': 191025,
#  'the dog': 155174,
#  'dog had': 44179,
#  'had grown': 65531,
#  'grown old': 64213,
#  'old and': 115438,
#  'and less': 13151,
#  'less capabl': 91369,
#  'capabl and': 31622,
#  'and one': 13556,
#  'one day': 116878,
#  'day the': 40079,
#  'the gilli': 156018,
#  'gilli had': 60882,
#  'had come': 65274,
#  'come and': 35431,
#  'and explain': 12222,
#  'explain with': 50080,
#  'with great': 187505,
#  'great sorrow': 63773,
#  'sorrow that': 144011,
#  'that the': 153211,
#  'had suffer': 66142,
#  'suffer a': 147876,
#  'a stroke': 4149,
#  'stroke and': 146840,
#  'and must': 13364,
#  'must be': 103544,
#  'be put': 22974,
#  'put down': 126761,
#  'yet the dog': 191026,
#  'the dog had': 155180,
#  'dog had grown': 44180,
#  'had grown old': 65534,
#  'grown old and': 64214,
#  'old and less': 115439,
#  'and less capabl': 13152,
#  'less capabl and': 91370,
#  'capabl and one': 31624,
#  'and one day': 13558,
#  'one day the': 116893,
#  'day the gilli': 40081,
#  'the gilli had': 156019,
#  'gilli had come': 60883,
#  'had come and': 65275,
#  'come and explain': 35432,
#  'and explain with': 12223,
#  'explain with great': 50081,
#  'with great sorrow': 187508,
#  'great sorrow that': 63775,
#  'sorrow that the': 144013,
#  'that the dog': 153230,
#  'dog had suffer': 44182,
#  'had suffer a': 66143,
#  'suffer a stroke': 147881,
#  'a stroke and': 4150,
#  'stroke and must': 146841,
#  'and must be': 13365,
#  'must be put': 103565,
#  'be put down': 22975,
#  'when': 183837,
#  'get': 60355,
#  'into': 83697,
#  'tube': 171675,
#  'or': 117951,
#  'train': 170716,
#  'without': 188335,
#  'pay': 121826,
#  'for': 55460,
#  'ticket': 164756,
#  'when i': 184100,
#  'i get': 76813,
#  'get into': 60527,
#  'into the': 83866,
#  'the tube': 159800,
#  'tube or': 171678,
#  'or the': 118221,
#  'the train': 159719,
#  'train without': 170791,
#  'without pay': 188445,
#  'pay for': 121845,
#  'for the': 56508,
#  'the ticket': 159612,
#  'when i get': 184161,
#  'i get into': 76823,
#  'get into the': 60530,
#  'into the tube': 83914,
#  'the tube or': 159802,
#  'tube or the': 171679,
#  'or the train': 118231,
#  'the train without': 159734,
#  'train without pay': 170792,
#  'without pay for': 188446,
#  'pay for the': 121853,
#  'for the ticket': 56641,
#  'thi': 162458,
#  'last': 89929,
#  'may': 97524,
#  'sourc': 144183,
#  'consider': 36730,
#  'disquiet': 43187,
#  'might': 100077,
#  'not': 109455,
#  'at': 19029,
#  'first': 54282,
#  'see': 136571,
#  'how': 74926,
#  'such': 147568,
#  'obvious': 111379,
#  'immor': 80159,
#  'content': 36899,
#  'could': 37405,
#  'defend': 40743,
#  'as': 18044,
#  'part': 121146,
#  'system': 148902,
#  'moral': 101664,
#  'thi last': 162805,
#  'last may': 90002,
#  'may be': 97530,
#  'be a': 22187,
#  'a sourc': 4016,
#  'sourc of': 144186,
#  'of consider': 112051,
#  'consider disquiet': 36743,
#  'disquiet and': 43200,
#  'one might': 117045,
#  'might not': 100156,
#  'not at': 109564,
#  'at first': 19309,
#  'first see': 54534,
#  'see how': 136674,
#  'how such': 75137,
#  'such obvious': 147659,
#  'obvious immor': 111390,
#  'immor content': 80160,
#  'content could': 36908,
#  'could be': 37421,
#  'be defend': 22489,
#  'defend as': 40744,
#  'as part': 18458,
#  'part of': 121174,
#  'of a': 111541,
#  'a system': 4272,
#  'system of': 148905,
#  'of moral': 113075,
#  'thi last may': 162807,
#  'last may be': 90003,
#  'may be a': 97531,
#  'be a sourc': 22219,
#  'a sourc of': 4017,
#  'sourc of consider': 144188,
#  'of consider disquiet': 112052,
#  'consider disquiet and': 36744,
#  'disquiet and one': 43202,
#  'and one might': 13561,
#  'one might not': 117046,
#  'might not at': 100157,
#  'not at first': 109566,
#  'at first see': 19318,
#  'first see how': 54535,
#  'see how such': 136680,
#  'how such obvious': 75138,
#  'such obvious immor': 147660,
#  'obvious immor content': 111391,
#  'immor content could': 80161,
#  'content could be': 36909,
#  'could be defend': 37426,
#  'be defend as': 22490,
#  'defend as part': 40745,
#  'as part of': 18459,
#  'part of a': 121175,
#  'of a system': 111656,
#  'a system of': 4273,
#  'system of moral': 148906,
#  'she': 138284,
#  'dislik': 43059,
#  'intimaci': 83683,
#  'he': 68450,
#  'show': 139740,
#  'toward': 170461,
#  'some': 142609,
#  'them': 160785,
#  'wa': 176563,
#  'resent': 130577,
#  'memori': 99540,
#  'they': 161833,
#  'share': 138179,
#  'which': 185136,
#  'felt': 52791,
#  'exclud': 49648,
#  'she dislik': 138432,
#  'dislik the': 43067,
#  'the intimaci': 156601,
#  'intimaci he': 83684,
#  'he show': 69242,
#  'show toward': 139828,
#  'toward some': 170497,
#  'some of': 142847,
#  'of them': 114297,
#  'them wa': 161010,
#  'wa resent': 178764,
#  'resent of': 130594,
#  'of the': 113889,
#  'the memori': 157180,
#  'memori they': 99549,
#  'they share': 162278,
#  'share of': 138215,
#  'of which': 114579,
#  'which she': 185398,
#  'she wa': 138967,
#  'wa not': 178310,
#  'not a': 109456,
#  'a part': 3028,
#  'part and': 121150,
#  'and felt': 12280,
#  'felt exclud': 52920,
#  'she dislik the': 138433,
#  'dislik the intimaci': 43068,
#  'the intimaci he': 156602,
#  'intimaci he show': 83685,
#  'he show toward': 69245,
#  'show toward some': 139829,
#  'toward some of': 170499,
#  'some of them': 142853,
#  'of them wa': 114319,
#  'them wa resent': 161011,
#  'wa resent of': 178765,
#  'resent of the': 130599,
#  'of the memori': 114086,
#  'the memori they': 157182,
#  'memori they share': 99550,
#  'they share of': 162279,
#  'share of which': 138216,
#  'of which she': 114585,
#  'which she wa': 185403,
#  'she wa not': 139026,
#  'wa not a': 178311,
#  'not a part': 109473,
#  'a part and': 3030,
#  'part and felt': 121151,
#  'and felt exclud': 12283,
#  'my': 103646,
#  'famili': 51080,
#  'heard': 69923,
#  'mother': 102291,
#  's': 132578,
#  'cousin': 38088,
#  'who': 185724,
#  'live': 92931,
#  'in': 80413,
#  'england': 47423,
#  'wrote': 190236,
#  'us': 174267,
#  'to': 165499,
#  'tell': 151058,
#  'cancer': 31524,
#  'lymph': 95022,
#  'gland': 61532,
#  'when my': 184320,
#  'my famili': 104455,
#  'famili heard': 51151,
#  'heard that': 70008,
#  'that my': 152792,
#  'my mother': 105400,
#  'mother s': 102491,
#  's cousin': 132907,
#  'cousin who': 38121,
#  'who live': 185940,
#  'live in': 92981,
#  'in england': 81020,
#  'england wrote': 47454,
#  'wrote us': 190264,
#  'us to': 174454,
#  'to tell': 168705,
#  'tell that': 151129,
#  'that he': 152430,
#  'he had': 68771,
#  'had cancer': 65247,
#  'cancer of': 31557,
#  'the lymph': 157009,
#  'lymph gland': 95023,
#  'when my famili': 184349,
#  'my famili heard': 104467,
#  'famili heard that': 51152,
#  'heard that my': 70015,
#  'that my mother': 152842,
#  'my mother s': 105447,
#  'mother s cousin': 102496,
#  's cousin who': 132908,
#  'cousin who live': 38123,
#  'who live in': 185943,
#  'live in england': 92988,
#  'in england wrote': 81027,
#  'england wrote us': 47455,
#  'wrote us to': 190265,
#  'us to tell': 174469,
#  'to tell that': 168716,
#  'tell that he': 151130,
#  'that he had': 152445,
#  'he had cancer': 68782,
#  'had cancer of': 65250,
#  'cancer of the': 31558,
#  'of the lymph': 114077,
#  'the lymph gland': 157010,
#  'find': 53915,
#  'out': 119318,
#  'am': 9846,
#  'chosen': 33877,
#  'collect': 35252,
#  'norm': 109385,
#  'chines': 33761,
#  'aphasia': 16652,
#  'will': 186501,
#  'contribut': 37025,
#  'china': 33731,
#  'catch': 32298,
#  'up': 173712,
#  'west': 183398,
#  'neuropsycholog': 107527,
#  'find out': 54009,
#  'out i': 119454,
#  'i am': 75743,
#  'am chosen': 9903,
#  'chosen to': 33885,
#  'to collect': 166205,
#  'collect norm': 35263,
#  'norm for': 109386,
#  'for chines': 55739,
#  'chines aphasia': 33764,
#  'aphasia i': 16653,
#  'i will': 79364,
#  'will contribut': 186580,
#  'contribut to': 37026,
#  'to china': 166168,
#  'china s': 33751,
#  's catch': 132858,
#  'catch up': 32321,
#  'up with': 174091,
#  'with the': 188000,
#  'the west': 160176,
#  'west in': 183403,
#  'in neuropsycholog': 81628,
#  'find out i': 54011,
#  'out i am': 119455,
#  'i am chosen': 75762,
#  'am chosen to': 9904,
#  'chosen to collect': 33886,
#  'to collect norm': 166207,
#  'collect norm for': 35264,
#  'norm for chines': 109388,
#  'for chines aphasia': 55740,
#  'chines aphasia i': 33765,
#  'aphasia i will': 16654,
#  'i will contribut': 79369,
#  'will contribut to': 186581,
#  'contribut to china': 37027,
#  'to china s': 166170,
#  'china s catch': 33752,
#  's catch up': 132859,
#  'catch up with': 32322,
#  'up with the': 174117,
#  'with the west': 188107,
#  'the west in': 160179,
#  'west in neuropsycholog': 183404,
#  'spokesperson': 144731,
#  'said': 134424,
#  'glen': 61601,
#  'is': 84238,
#  'furiou': 59661,
#  'new': 107771,
#  'anarchi': 11244,
#  'promo': 126133,
#  'featur': 52131,
#  'footag': 55401,
#  'sid': 139996,
#  'viciou': 176066,
#  'well': 182246,
#  'himself': 73315,
#  'a spokesperson': 4049,
#  'spokesperson said': 144732,
#  'said glen': 134482,
#  'glen is': 61602,
#  'is furiou': 84586,
#  'furiou that': 59686,
#  'the new': 157456,
#  'new anarchi': 107774,
#  'anarchi promo': 11245,
#  'promo featur': 126134,
#  'featur footag': 52132,
#  'footag of': 55402,
#  'of sid': 113668,
#  'sid viciou': 139997,
#  'viciou as': 176067,
#  'as well': 18631,
#  'well as': 182265,
#  'as himself': 18300,
#  'a spokesperson said': 4050,
#  'spokesperson said glen': 144733,
#  'said glen is': 134483,
#  'glen is furiou': 61603,
#  'is furiou that': 84588,
#  'furiou that the': 59690,
#  'that the new': 153268,
#  'the new anarchi': 157457,
#  'new anarchi promo': 107775,
#  'anarchi promo featur': 11246,
#  'promo featur footag': 126135,
#  'featur footag of': 52133,
#  'footag of sid': 55403,
#  'of sid viciou': 113669,
#  'sid viciou as': 139998,
#  'viciou as well': 176068,
#  'as well as': 18633,
#  'well as himself': 182269,
#  'ye': 190358,
#  'peopl': 122061,
#  'burn': 28813,
#  'feel': 52197,
#  'sad': 134121,
#  'actual': 6509,
#  'can': 31087,
#  'even': 48211,
#  'express': 50144,
#  'lot': 94355,
#  'i see': 78367,
#  'see peopl': 136775,
#  'peopl with': 122354,
#  'with burn': 187335,
#  'burn i': 28816,
#  'i feel': 76554,
#  'feel sad': 52523,
#  'sad actual': 134135,
#  'actual i': 6529,
#  'i can': 76056,
#  'can not': 31265,
#  'not even': 109786,
#  'even express': 48280,
#  'express my': 50206,
#  'my feel': 104598,
#  'feel as': 52245,
#  'as i': 18301,
#  'think that': 163696,
#  'that they': 153340,
#  'they must': 162156,
#  'must suffer': 103615,
#  'a lot': 2459,
#  'when i see': 184224,
#  'i see peopl': 78379,
#  'see peopl with': 136777,
#  'peopl with burn': 122356,
#  'with burn i': 187336,
#  'burn i feel': 28817,
#  'i feel sad': 76597,
#  'feel sad actual': 52525,
#  'sad actual i': 134136,
#  'actual i can': 6530,
#  'i can not': 76073,
#  'can not even': 31268,
#  'not even express': 109789,
#  'even express my': 48281,
#  'express my feel': 50209,
#  'my feel as': 104599,
#  'feel as i': 52247,
#  'as i think': 18329,
#  'i think that': 78661,
#  'think that they': 163707,
#  'that they must': 153351,
#  'they must suffer': 162159,
#  'must suffer a': 103616,
#  'suffer a lot': 147878,
#  'gone': 62250,
#  'hospit': 74427,
#  'research': 130547,
#  'got': 62737,
#  'late': 90152,
#  'reach': 128146,
#  'home': 73731,
#  'fear': 51873,
#  'would': 189512,
#  'quarrel': 126915,
#  'becaus': 23673,
#  'i had': 76932,
#  'had gone': 65488,
#  'gone to': 62303,
#  'to the': 168740,
#  'the hospit': 156378,
#  'hospit for': 74452,
#  'for my': 56177,
#  'my research': 105898,
#  'research and': 130552,
#  'and got': 12470,
#  'got late': 62918,
#  'late in': 90198,
#  'in reach': 81788,
#  'reach home': 128158,
#  'home i': 73864,
#  'i fear': 76534,
#  'fear that': 52058,
#  'that when': 153509,
#  'i reach': 78157,
#  'home there': 73964,
#  'there would': 161685,
#  'would be': 189534,
#  'a quarrel': 3408,
#  'quarrel becaus': 126917,
#  'becaus of': 23796,
#  'of my': 113107,
#  'my be': 103790,
#  'be late': 22766,
#  'i had gone': 76982,
#  'had gone to': 65503,
#  'gone to the': 62315,
#  'to the hospit': 168844,
#  'the hospit for': 156383,
#  'hospit for my': 74454,
#  'for my research': 56227,
#  'my research and': 105899,
#  'research and got': 130554,
#  'and got late': 12478,
#  'got late in': 62919,
#  'late in reach': 90200,
#  'in reach home': 81789,
#  'reach home i': 128160,
#  'home i fear': 73868,
#  'i fear that': 76548,
#  'fear that when': 52072,
#  'that when i': 153510,
#  'when i reach': 184207,
#  'i reach home': 78158,
#  'reach home there': 128161,
#  'home there would': 73966,
#  'there would be': 161686,
#  'would be a': 189535,
#  'be a quarrel': 22215,
#  'a quarrel becaus': 3409,
#  'quarrel becaus of': 126918,
#  'becaus of my': 23811,
#  'of my be': 113115,
#  'my be late': 103792,
#  'from': 58656,
#  'friend': 57845,
#  'boy': 27399,
#  'love': 94520,
#  'her': 70510,
#  'me': 97735,
#  'day i': 39944,
#  'i heard': 77218,
#  'heard from': 69950,
#  'from a': 58657,
#  'a friend': 1586,
#  'friend that': 58323,
#  'the boy': 154181,
#  'boy i': 27450,
#  'i love': 77638,
#  'love had': 94595,
#  'gone out': 62288,
#  'out with': 119681,
#  'with her': 187533,
#  'her and': 70550,
#  'and not': 13484,
#  'not with': 110689,
#  'with me': 187698,
#  'one day i': 116886,
#  'day i heard': 39961,
#  'i heard from': 77226,
#  'heard from a': 69951,
#  'from a friend': 58673,
#  'a friend that': 1627,
#  'friend that the': 58328,
#  'that the boy': 153219,
#  'the boy i': 154185,
#  'boy i love': 27458,
#  'i love had': 77650,
#  'love had gone': 94596,
#  'had gone out': 65500,
#  'gone out with': 62293,
#  'out with her': 119686,
#  'with her and': 187535,
#  'her and not': 70563,
#  'and not with': 13503,
#  'not with me': 110690,
#  'connor': 36638,
#  'voic': 176426,
#  'gleeful': 61588,
#  'connor s': 36639,
#  's voic': 134020,
#  'voic wa': 176478,
#  'wa gleeful': 177663,
#  'connor s voic': 36640,
#  's voic wa': 134024,
#  'voic wa gleeful': 176481,
#  'veri': 175255,
#  'funni': 59631,
#  'what': 183439,
#  'wrong': 190159,
#  'you': 191071,
#  'today': 169367,
#  'secretari': 136504,
#  'suppos': 148308,
#  'talk': 150357,
#  'tone': 169802,
#  'do': 43448,
#  'know': 89161,
#  'veri funni': 175490,
#  'funni what': 59645,
#  'what s': 183658,
#  's wrong': 134071,
#  'wrong with': 190223,
#  'with you': 188247,
#  'you today': 192203,
#  'today you': 169430,
#  'you are': 191140,
#  'are my': 17284,
#  'my secretari': 105980,
#  'secretari and': 136505,
#  'and you': 15205,
#  'are not': 17303,
#  'not suppos': 110488,
#  'suppos to': 148321,
#  'to talk': 168690,
#  'talk to': 150450,
#  'to me': 167544,
#  'me in': 98319,
#  'in that': 81950,
#  'that tone': 153395,
#  'tone of': 169807,
#  'of voic': 114514,
#  'voic do': 176448,
#  'do you': 43891,
#  'you know': 191644,
#  'know that': 89342,
#  'veri funni what': 175492,
#  'funni what s': 59646,
#  'what s wrong': 183672,
#  's wrong with': 134075,
#  'wrong with you': 190230,
#  'with you today': 188261,
#  'you today you': 192204,
#  'today you are': 169431,
#  'you are my': 191167,
#  'are my secretari': 17289,
#  'my secretari and': 105981,
#  'secretari and you': 136506,
#  'and you are': 15206,
#  'you are not': 191170,
#  'are not suppos': 17318,
#  'not suppos to': 110489,
#  'suppos to talk': 148336,
#  'to talk to': 168694,
#  'talk to me': 150459,
#  'to me in': 167570,
#  'me in that': 98339,
#  'in that tone': 81960,
#  'that tone of': 153396,
#  'tone of voic': 169808,
#  'of voic do': 114515,
#  'voic do you': 176449,
#  'do you know': 43906,
#  'you know that': 191663,
#  'perhap': 122485,
#  'we': 180975,
#  'need': 107142,
#  'have': 67423,
#  'more': 101682,
#  'babi': 21076,
#  'tina': 165418,
#  'gave': 60076,
#  'birth': 26214,
#  'yesterday': 190938,
#  'perhap we': 122526,
#  'we need': 181433,
#  'need to': 107222,
#  'to have': 167005,
#  'have more': 67963,
#  'more babi': 101709,
#  'babi tina': 21120,
#  'tina gave': 165421,
#  'gave birth': 60089,
#  'birth to': 26229,
#  'to a': 165500,
#  'a babi': 20,
#  'babi boy': 21085,
#  'boy yesterday': 27530,
#  'perhap we need': 122528,
#  'we need to': 181434,
#  'need to have': 107236,
#  'to have more': 167026,
#  'have more babi': 67964,
#  'more babi tina': 101710,
#  'babi tina gave': 21121,
#  'tina gave birth': 165422,
#  'gave birth to': 60090,
#  'birth to a': 26230,
#  'to a babi': 165502,
#  'a babi boy': 22,
#  'babi boy yesterday': 21087,
#  'whi': 185009,
#  'happi': 66916,
#  'way': 180742,
#  'play': 123735,
#  'but': 28957,
#  'accept': 5952,
#  'believ': 25260,
#  'should': 139509,
#  'fli': 54918,
#  'half': 66489,
#  'am veri': 10175,
#  'veri happi': 175522,
#  'happi with': 67076,
#  'the way': 160092,
#  'way i': 180801,
#  'am play': 10064,
#  'play but': 123773,
#  'but i': 29188,
#  'i accept': 75666,
#  'accept that': 6026,
#  'he believ': 68527,
#  'believ he': 25267,
#  'he should': 69236,
#  'should be': 139522,
#  'be england': 22550,
#  'england s': 47437,
#  's fli': 133107,
#  'fli half': 54929,
#  'i am veri': 75856,
#  'am veri happi': 10180,
#  'veri happi with': 175538,
#  'happi with the': 67079,
#  'with the way': 188106,
#  'the way i': 160104,
#  'way i am': 180803,
#  'i am play': 75818,
#  'am play but': 10065,
#  'play but i': 123774,
#  'but i accept': 29189,
#  'i accept that': 75669,
#  'accept that he': 6027,
#  'that he believ': 152434,
#  'he believ he': 68528,
#  'believ he should': 25269,
#  'he should be': 69237,
#  'should be england': 139533,
#  'be england s': 22551,
#  'england s fli': 47438,
#  's fli half': 133108,
#  'leav': 90810,
#  'carriag': 32152,
#  'go': 61689,
#  'shop': 139366,
#  'someth': 143343,
#  'happen': 66781,
#  'i have': 77131,
#  'have to': 68258,
#  'to leav': 167395,
#  'leav the': 90934,
#  'the babi': 153911,
#  'babi in': 21108,
#  'in the': 81965,
#  'the carriag': 154378,
#  'carriag and': 32153,
#  'and go': 12454,
#  'go shop': 61898,
#  'shop i': 139381,
#  'that someth': 153152,
#  'someth will': 143537,
#  'will happen': 186638,
#  'happen to': 66883,
#  'when i have': 184165,
#  'i have to': 77195,
#  'have to leav': 68287,
#  'to leav the': 167414,
#  'leav the babi': 90936,
#  'the babi in': 153915,
#  'babi in the': 21109,
#  'in the carriag': 82001,
#  'the carriag and': 154379,
#  'carriag and go': 32154,
#  'and go shop': 12459,
#  'go shop i': 61901,
#  'shop i fear': 139382,
#  'fear that someth': 52068,
#  'that someth will': 153160,
#  'someth will happen': 143538,
#  'will happen to': 186639,
#  'happen to the': 66895,
#  'to the babi': 168755,
#  'no': 108692,
#  'use': 174525,
#  'now': 110925,
#  'someon': 143121,
#  'els': 46975,
#  'janet': 87033,
#  'appreci': 16881,
#  'much': 103069,
#  'beauti': 23487,
#  'fun': 59548,
#  'm': 95035,
#  'dumb': 45760,
#  'uninterest': 173158,
#  'no you': 109137,
#  'you use': 192233,
#  'use to': 174636,
#  'to be': 165780,
#  'be but': 22385,
#  'but not': 29370,
#  'not now': 110188,
#  'now you': 111139,
#  'are in': 17233,
#  'in love': 81436,
#  'love with': 94737,
#  'with someon': 187951,
#  'someon els': 143166,
#  'els you': 47032,
#  'with my': 187757,
#  'my friend': 104721,
#  'friend janet': 58163,
#  'janet you': 87041,
#  'you appreci': 191138,
#  'appreci her': 16890,
#  'her veri': 71371,
#  'veri much': 175660,
#  'much you': 103349,
#  'you think': 192160,
#  'think she': 163675,
#  'she is': 138599,
#  'is beauti': 84424,
#  'beauti and': 23488,
#  'and fun': 12393,
#  'fun to': 59578,
#  'be with': 23312,
#  'with and': 187285,
#  'think i': 163594,
#  'i m': 77677,
#  'm dumb': 95144,
#  'dumb and': 45761,
#  'and uninterest': 14839,
#  'no you use': 109142,
#  'you use to': 192236,
#  'use to be': 174637,
#  'to be but': 165804,
#  'be but not': 22386,
#  'but not now': 29379,
#  'not now you': 110193,
#  'now you are': 111140,
#  'you are in': 191163,
#  'are in love': 17237,
#  'in love with': 81446,
#  'love with someon': 94746,
#  'with someon els': 187954,
#  'someon els you': 143173,
#  'els you are': 47033,
#  'love with my': 94744,
#  'with my friend': 187785,
#  'my friend janet': 104762,
#  'friend janet you': 58164,
#  'janet you appreci': 87042,
#  'you appreci her': 191139,
#  'appreci her veri': 16891,
#  'her veri much': 71373,
#  'veri much you': 175691,
#  'much you think': 103352,
#  'you think she': 192168,
#  'think she is': 163676,
#  'she is beauti': 138606,
#  'is beauti and': 84425,
#  'beauti and fun': 23490,
#  'and fun to': 12394,
#  'fun to be': 59579,
#  'to be with': 165923,
#  'be with and': 23314,
#  'with and you': 187288,
#  'and you think': 15221,
#  'you think i': 192163,
#  'think i m': 163606,
#  'i m dumb': 77710,
#  'm dumb and': 95145,
#  'dumb and uninterest': 45762,
#  'wow': 189993,
#  'so': 141739,
#  'thought': 164030,
#  'were': 182668,
#  'an': 10463,
#  'assist': 18947,
#  'wow whi': 190011,
#  'whi so': 185110,
#  'so much': 142112,
#  'much i': 103196,
#  'i thought': 78673,
#  'thought they': 164161,
#  'they were': 162375,
#  'were get': 182929,
#  'get you': 60815,
#  'you an': 191119,
#  'an assist': 10643,
#  'wow whi so': 190012,
#  'whi so much': 185111,
#  'so much i': 142123,
#  'much i thought': 103204,
#  'i thought they': 78694,
#  'thought they were': 164165,
#  'they were get': 162392,
#  'were get you': 182931,
#  'get you an': 60817,
#  'you an assist': 191120,
#  'infiltr': 82911,
#  'our': 118813,
#  'illus': 80014,
#  'their': 160439,
#  'polit': 124418,
#  'solut': 142583,
#  'infiltr in': 82912,
#  'in our': 81680,
#  'our live': 119059,
#  'live the': 93058,
#  'the illus': 156477,
#  'illus of': 80017,
#  'of so': 113691,
#  'so we': 142330,
#  'we accept': 180976,
#  'accept their': 6035,
#  'their polit': 160696,
#  'polit solut': 124430,
#  'infiltr in our': 82913,
#  'in our live': 81694,
#  'our live the': 119060,
#  'live the illus': 93059,
#  'the illus of': 156478,
#  'illus of so': 80018,
#  'of so we': 113694,
#  'so we accept': 142331,
#  'we accept their': 180978,
#  'accept their polit': 6036,
#  'their polit solut': 160697,
#  'spontan': 144737,
#  'picnic': 123244,
#  'sister': 140520,
#  'children': 33611,
#  'spontan picnic': 144741,
#  'picnic with': 123256,
#  'with sister': 187927,
#  'sister and': 140532,
#  'and friend': 12371,
#  'friend and': 57875,
#  'and children': 11786,
#  'children great': 33637,
#  'spontan picnic with': 144742,
#  ...}

# %%
print(X_train_vect)
# Out:
#   (0, 169800)	0.22466800904005915
#   (0, 169799)	0.215220164290722
#   (0, 169798)	0.215220164290722
#   (0, 163569)	0.22466800904005915
#   (0, 163568)	0.22466800904005915
#   (0, 163547)	0.11089260991482865
#   (0, 161423)	0.22466800904005915
#   (0, 161405)	0.1640220802361927
#   (0, 161383)	0.1000182946039042
#   (0, 152588)	0.215220164290722
#   (0, 152508)	0.09550398557644205
#   (0, 152048)	0.06335026209123826
#   (0, 120630)	0.22466800904005915
#   (0, 120629)	0.215220164290722
#   (0, 120612)	0.18291776973486704
#   (0, 118644)	0.22466800904005915
#   (0, 118643)	0.22466800904005915
#   (0, 118463)	0.11360402725107643
#   (0, 113330)	0.22466800904005915
#   (0, 113324)	0.1793258658647461
#   (0, 111540)	0.05866812655415145
#   (0, 78642)	0.22466800904005915
#   (0, 78639)	0.13237610238972086
#   (0, 75663)	0.04115458758046488
#   (0, 25693)	0.14503069757543816
#   :	:
#   (7933, 151767)	0.11643272376990398
#   (7933, 127899)	0.20951256945582394
#   (7933, 127898)	0.1768298420334078
#   (7933, 127897)	0.11173432132619529
#   (7933, 101450)	0.20951256945582394
#   (7933, 101449)	0.20951256945582394
#   (7933, 101444)	0.19445088418988504
#   (7933, 97735)	0.0641379572780909
#   (7933, 78810)	0.20951256945582394
#   (7933, 78802)	0.12091005131447266
#   (7933, 75663)	0.03837842078949714
#   (7933, 38298)	0.20951256945582394
#   (7933, 38296)	0.20070204837758535
#   (7933, 38295)	0.17938919892394609
#   (7933, 25702)	0.20951256945582394
#   (7933, 25701)	0.20951256945582394
#   (7933, 25693)	0.1352473555484381
#   (7933, 22171)	0.20951256945582394
#   (7933, 22170)	0.20951256945582394
#   (7933, 22169)	0.20951256945582394
#   (7933, 2734)	0.20951256945582394
#   (7933, 2733)	0.20951256945582394
#   (7933, 134)	0.20951256945582394
#   (7933, 132)	0.18564036311164642
#   (7933, 0)	0.07780946366525696

# %%
print(vect.idf_)
# Out:
# [2.11489886 8.94873845 9.64188564 ... 9.64188564 9.64188564 9.64188564]

# %%
print(vect.fit_transform(total_data.Text))
# Out:
#   (0, 163569)	0.22466800904005915
#   (0, 78642)	0.22466800904005915
#   (0, 152588)	0.215220164290722
#   (0, 120630)	0.22466800904005915
#   (0, 118644)	0.22466800904005915
#   (0, 113330)	0.22466800904005915
#   (0, 169800)	0.22466800904005915
#   (0, 17483)	0.22466800904005915
#   (0, 161423)	0.22466800904005915
#   (0, 17088)	0.215220164290722
#   (0, 163568)	0.22466800904005915
#   (0, 78639)	0.13237610238972086
#   (0, 152508)	0.09550398557644205
#   (0, 120629)	0.215220164290722
#   (0, 118643)	0.22466800904005915
#   (0, 113324)	0.1793258658647461
#   (0, 169799)	0.215220164290722
#   (0, 17482)	0.22466800904005915
#   (0, 161405)	0.1640220802361927
#   (0, 25693)	0.14503069757543816
#   (0, 163547)	0.11089260991482865
#   (0, 75663)	0.04115458758046488
#   (0, 152048)	0.06335026209123826
#   (0, 120612)	0.18291776973486704
#   (0, 118463)	0.11360402725107643
#   :	:
#   (11326, 147323)	0.22659420984478004
#   (11326, 184558)	0.22659420984478004
#   (11326, 132532)	0.22659420984478004
#   (11326, 98092)	0.22659420984478004
#   (11326, 122259)	0.22659420984478004
#   (11326, 184557)	0.22659420984478004
#   (11326, 147322)	0.21706536359355214
#   (11326, 165122)	0.20506043707160038
#   (11326, 45876)	0.21030453958475395
#   (11326, 126727)	0.19124684708229805
#   (11326, 126715)	0.1691965474398386
#   (11326, 132509)	0.17368654162231745
#   (11326, 165109)	0.17133447761037235
#   (11326, 82017)	0.19124684708229805
#   (11326, 154560)	0.17248109655154809
#   (11326, 45799)	0.1269186774295835
#   (11326, 147295)	0.16001078796070245
#   (11326, 34112)	0.1573968713622913
#   (11326, 164893)	0.09185480455222036
#   (11326, 81965)	0.09045244350853097
#   (11326, 97735)	0.06936714960937768
#   (11326, 122061)	0.11467823399664942
#   (11326, 80413)	0.06210059693818811
#   (11326, 183837)	0.06056512070341743
#   (11326, 153603)	0.0465625878895579

# %%
rf = RandomForestClassifier(n_estimators=50)
rf.fit(X_train_vect, y_train)

yrf_pred = rf.predict(X_test_vect)
class_names = ['joy', 'sadness', 'anger', 'neutral', 'fear']

print("Accuracy: {:.2f}%".format(accuracy_score(y_test, yrf_pred) * 100))
print("\nF1 Score: {:.2f}".format(f1_score(y_test, yrf_pred, average='micro') * 100))
cf =  confusion_matrix(y_test, yrf_pred)
print("\nConfusion Matrix:\n", cf)
# Out:
# Accuracy: 63.01%
#
# F1 Score: 63.01
#
# Confusion Matrix:
#  [[396  63  55 105  74]
#  [ 65 424  36  97  57]
#  [ 75  63 406 122  41]
#  [ 40  11  40 526  21]
#  [ 83  54  70  83 386]]

# %%
#Create pipeline with our tf-idf vectorizer and RandomForest model
rf_model = Pipeline([
    ('tfidf', vect),
    ('clf', rf),
])

# %%
# save the model
filename = r'./Models/tfidf_rf.sav'
pickle.dump(rf_model, open(filename, 'wb'))

# %%
model = pickle.load(open(filename, 'rb'))

message = "If you don't shut up, I'll kill you"

print(model.predict([message]))
# Out:
# ['anger']

# %%
# import seaborn as sns

# plt.figure(figsize=(20, 8)) 

# cf_plot = sns.heatmap(cf, annot=True, cmap = 'Blues')
# cf_plot.set_title('\n confusion matrix \n')
# cf_plot.set_xlabel('\n Predicted label \n')
# cf_plot.set_xticklabels(['joy', 'sadness', 'anger', 'neutral', 'fear'])
# cf_plot.set_ylabel('\nTrue label\n')
# cf_plot.set_yticklabels(['joy', 'sadness', 'anger', 'neutral', 'fear'])
# plt.show()
